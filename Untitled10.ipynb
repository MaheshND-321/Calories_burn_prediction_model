# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheshND-321/Calories_burn_prediction_model/blob/master/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Audio Processing Libraries
import librosa
from scipy import signal
#For Playing Audio
import IPython.display as ipd
#Array Processing
import numpy as np
#Data Visualization
import matplotlib.pyplot as plt

# %%
path='emergency.wav'
emergency,sample_rate    = librosa.load(path, sr = 16000)
path='non emergency.wav'
non_emergency,sample_rate= librosa.load(path, sr =16000)

# %%
# duration1 = librosa.get_duration(emergency,sr=16000)
# duration2 = librosa.get_duration(non_emergency,sr=16000)
# print("Duration of an emergency and Non Emergency (in min):",duration1/60,duration2/60)

# %%
def prepare_data(samples, num_of_samples=32000, num_of_common=16000):
  data=[]
  for offset in range(0, len(samples), num_of_common):
    start = offset
    end   = offset + num_of_samples
    chunk = samples[start:end]
    if(len(chunk)==32000):
      data.append(chunk)
  return data

# %%
emergency = prepare_data(emergency)
non_emergency = prepare_data(non_emergency)

# %%
print("No. of Chunks of Emergency and Non Emergency:",len(emergency),len(non_emergency))
# Out:
# No. of Chunks of Emergency and Non Emergency: 1374 1628

# %%
plt.figure(figsize=(14,4))
plt.plot(np.linspace(0, 2, num=32000),emergency[103])
plt.title('Emergency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.figure(figsize=(14,4))
plt.plot(np.linspace(0, 2, num=32000),non_emergency[102])
plt.title('Non Emergency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
audio = np.concatenate([emergency,non_emergency])
labels1 = np.zeros(len(emergency))
labels2 = np.ones(len(non_emergency))
labels = np.concatenate([labels1,labels2])
print(audio.shape)
# Out:
# (3002, 32000)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(audio),np.array(labels),
                                             stratify=labels,test_size = 0.1,
                                                   random_state=777,shuffle=True)

# %%
x_tr_features  = x_tr.reshape(len(x_tr),-1,1)
x_val_features = x_val.reshape(len(x_val),-1,1)
print("Reshaped Array Size",x_tr_features.shape)
# Out:
# Reshaped Array Size (2701, 32000, 1)

# %%
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from keras import backend as K
def cnn(x_tr):
  K.clear_session()
  inputs = Input(shape=(x_tr.shape[1],x_tr.shape[2]))
  #First Conv1D layer
  conv = Conv1D(8, 13, padding='same', activation='relu')(inputs)
  conv = Dropout(0.3)(conv)
  conv = MaxPooling1D(2)(conv)
  #Second Conv1D layer
  conv = Conv1D(16, 11, padding='same', activation='relu')(conv)
  conv = Dropout(0.3)(conv)
  conv = MaxPooling1D(2)(conv)
  #MaxPooling 1D
  conv = GlobalMaxPool1D()(conv)
  #Dense Layer 
  conv = Dense(16, activation='relu')(conv)
  outputs = Dense(1,activation='sigmoid')(conv)
  model = Model(inputs, outputs)
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])
  model_checkpoint = ModelCheckpoint('best_model.hdf5', monitor='val_acc',
                                 verbose=1, save_best_only=True, mode='max')
  return model, model_checkpoint
model, model_checkpoint = cnn(x_tr_features)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32000, 1)]        0
#
#  conv1d (Conv1D)             (None, 32000, 8)          112
#
#  dropout (Dropout)           (None, 32000, 8)          0
#
#  max_pooling1d (MaxPooling1D  (None, 16000, 8)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 16000, 16)         1424
#
#  dropout_1 (Dropout)         (None, 16000, 16)         0
#
#  max_pooling1d_1 (MaxPooling  (None, 8000, 16)         0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 16)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,825
# Trainable params: 1,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_tr_features, y_tr ,epochs=10,       callbacks=[model_checkpoint], 
batch_size=32, validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.6060 - acc: 0.7216
# Epoch 1: val_acc improved from -inf to 0.81395, saving model to best_model.hdf5
# 85/85 [==============================] - 15s 32ms/step - loss: 0.6060 - acc: 0.7216 - val_loss: 0.5739 - val_acc: 0.8140
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4292 - acc: 0.8478
# Epoch 2: val_acc improved from 0.81395 to 0.86047, saving model to best_model.hdf5
# 85/85 [==============================] - 2s 27ms/step - loss: 0.4292 - acc: 0.8478 - val_loss: 0.4557 - val_acc: 0.8605
# Epoch 3/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.3587 - acc: 0.8607
# Epoch 3: val_acc did not improve from 0.86047
# 85/85 [==============================] - 2s 27ms/step - loss: 0.3572 - acc: 0.8619 - val_loss: 0.4070 - val_acc: 0.8605
# Epoch 4/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.3335 - acc: 0.8653
# Epoch 4: val_acc did not improve from 0.86047
# 85/85 [==============================] - 2s 26ms/step - loss: 0.3338 - acc: 0.8652 - val_loss: 0.3801 - val_acc: 0.8538
# Epoch 5/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.3218 - acc: 0.8694
# Epoch 5: val_acc did not improve from 0.86047
# 85/85 [==============================] - 2s 28ms/step - loss: 0.3219 - acc: 0.8697 - val_loss: 0.3925 - val_acc: 0.8405
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3127 - acc: 0.8782
# Epoch 6: val_acc did not improve from 0.86047
# 85/85 [==============================] - 2s 27ms/step - loss: 0.3127 - acc: 0.8782 - val_loss: 0.3690 - val_acc: 0.8605
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3104 - acc: 0.8763
# Epoch 7: val_acc improved from 0.86047 to 0.87043, saving model to best_model.hdf5
# 85/85 [==============================] - 2s 26ms/step - loss: 0.3104 - acc: 0.8763 - val_loss: 0.3581 - val_acc: 0.8704
# Epoch 8/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.3079 - acc: 0.8739
# Epoch 8: val_acc did not improve from 0.87043
# 85/85 [==============================] - 2s 27ms/step - loss: 0.3099 - acc: 0.8719 - val_loss: 0.3640 - val_acc: 0.8571
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3010 - acc: 0.8826
# Epoch 9: val_acc improved from 0.87043 to 0.87375, saving model to best_model.hdf5
# 85/85 [==============================] - 2s 27ms/step - loss: 0.3010 - acc: 0.8826 - val_loss: 0.3508 - val_acc: 0.8738
# Epoch 10/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.3090 - acc: 0.8761
# Epoch 10: val_acc did not improve from 0.87375
# 85/85 [==============================] - 2s 27ms/step - loss: 0.3087 - acc: 0.8763 - val_loss: 0.3535 - val_acc: 0.8605

# %%
#summarize history for loss
plt.plot(history.history['loss'])

plt.plot(history.history['val_loss'])

plt.title('Model loss')

plt.xlabel('Time')

plt.ylabel('epoch')

plt.legend(['train','validation'],loc = 'upper left')

plt.show()

# %%
_, acc = model.evaluate(x_val_features,y_val)
print("Validation Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3535 - acc: 0.8605
# Validation Accuracy: 0.8604651093482971

# %%
ind=35
test_audio = x_val[ind]
ipd.Audio(test_audio,rate=16000)
feature = x_val_features[ind]
prob = model.predict(feature.reshape(1,-1,1))
if (prob[0][0] < 0.5 ):
 pred='emergency'
else:
 pred='non emergency'
print("Prediction:",pred)
# Out:
# 1/1 [==============================] - 0s 252ms/step
# Prediction: emergency

# %%
import pickle

pickle.dump(model, open('audio_model.pkl','wb'))

pickled_model = pickle.load(open('audio_model.pkl','rb'))
# pickled_mmodel.predict()

ind=35
test_audio = x_val[ind]
ipd.Audio(test_audio,rate=16000)
feature = x_val_features[ind]
prob = pickled_model.predict(feature.reshape(1,-1,1))
if (prob[0][0] < 0.5 ):
 pred='emergency'
else:
 pred='non emergency'
print("Prediction:",pred)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# Prediction: emergency

# %%
x_tr_features  = x_tr.reshape(len(x_tr),-1,160)
x_val_features = x_val.reshape(len(x_val),-1,160)
print("Reshaped Array Size",x_tr_features.shape)
# Out:
# Reshaped Array Size (2701, 200, 160)

# %%
def lstm(x_tr):
  K.clear_session()
  inputs = Input(shape=(x_tr.shape[1],x_tr.shape[2]))
  #lstm
  x = LSTM(128)(inputs)
  x = Dropout(0.3)(x)
    #dense
  x= Dense(64,activation='relu')(x)
  x= Dense(1,activation='sigmoid')(x)
  model = Model(inputs, x)
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])
  return model

model = lstm(x_tr_features)
model.summary()
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True,mode='max')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 160)]        0
#
#  lstm (LSTM)                 (None, 128)               147968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 156,289
# Trainable params: 156,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_tr_features, y_tr, epochs=10, callbacks=[mc], batch_size=32,
                                         validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.7026 - acc: 0.5889
# Epoch 1: val_acc improved from -inf to 0.59468, saving model to best_model.hdf5
# 85/85 [==============================] - 6s 22ms/step - loss: 0.7025 - acc: 0.5890 - val_loss: 0.6806 - val_acc: 0.5947
# Epoch 2/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.6651 - acc: 0.6235
# Epoch 2: val_acc improved from 0.59468 to 0.66445, saving model to best_model.hdf5
# 85/85 [==============================] - 2s 19ms/step - loss: 0.6650 - acc: 0.6238 - val_loss: 0.6324 - val_acc: 0.6645
# Epoch 3/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.6128 - acc: 0.6604
# Epoch 3: val_acc did not improve from 0.66445
# 85/85 [==============================] - 2s 19ms/step - loss: 0.6132 - acc: 0.6594 - val_loss: 0.6715 - val_acc: 0.5748
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.6427 - acc: 0.5861
# Epoch 4: val_acc did not improve from 0.66445
# 85/85 [==============================] - 1s 13ms/step - loss: 0.6427 - acc: 0.5861 - val_loss: 0.6425 - val_acc: 0.5648
# Epoch 5/10
# 82/85 [===========================>..] - ETA: 0s - loss: 0.6488 - acc: 0.6395
# Epoch 5: val_acc did not improve from 0.66445
# 85/85 [==============================] - 1s 13ms/step - loss: 0.6486 - acc: 0.6383 - val_loss: 0.6220 - val_acc: 0.6645
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.5412 - acc: 0.7412
# Epoch 6: val_acc improved from 0.66445 to 0.84385, saving model to best_model.hdf5
# 85/85 [==============================] - 1s 13ms/step - loss: 0.5412 - acc: 0.7412 - val_loss: 0.4341 - val_acc: 0.8439
# Epoch 7/10
# 81/85 [===========================>..] - ETA: 0s - loss: 0.6161 - acc: 0.6578
# Epoch 7: val_acc did not improve from 0.84385
# 85/85 [==============================] - 1s 13ms/step - loss: 0.6187 - acc: 0.6549 - val_loss: 0.6602 - val_acc: 0.5880
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.6610 - acc: 0.5961
# Epoch 8: val_acc did not improve from 0.84385
# 85/85 [==============================] - 1s 13ms/step - loss: 0.6610 - acc: 0.5961 - val_loss: 0.6408 - val_acc: 0.5183
# Epoch 9/10
# 81/85 [===========================>..] - ETA: 0s - loss: 0.5797 - acc: 0.7215
# Epoch 9: val_acc did not improve from 0.84385
# 85/85 [==============================] - 1s 14ms/step - loss: 0.5772 - acc: 0.7220 - val_loss: 0.5429 - val_acc: 0.7176
# Epoch 10/10
# 82/85 [===========================>..] - ETA: 0s - loss: 0.6317 - acc: 0.6395
# Epoch 10: val_acc did not improve from 0.84385
# 85/85 [==============================] - 1s 13ms/step - loss: 0.6302 - acc: 0.6427 - val_loss: 1.3460 - val_acc: 0.5515

# %%
model.load_weights('best_model.hdf5')

# %%
#summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Time')
plt.ylabel('epoch')
plt.legend(['train','validation'],loc = 'upper left')
plt.show()

# %%
_,acc = model.evaluate(x_val_features,y_val)
print("Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2770 - acc: 0.9269
# Accuracy: 0.9269102811813354

# %%
import pickle

pickle.dump(model, open('audio_model.pkl','wb'))

# %%
pickled_model = pickle.load(open('audio_model.pkl','rb'))
# pickled_mmodel.predict()

ind=35
test_audio = x_val[ind]
ipd.Audio(test_audio,rate=16000)
feature = x_val_features[ind]
prob = pickled_model.predict(feature.reshape(1,-1,1))
if (prob[0][0] < 0.5 ):
 pred='emergency'
else:
 pred='non emergency'
print("Prediction:",pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-3b29b826185e> in <cell line: 12>()
#      10 ipd.Audio(test_audio,rate=16000)
#      11 feature = x_val_features[ind]
# ---> 12 prob = pickled_model.predict(feature.reshape(1,-1,1))
#      13 if (prob[0][0] < 0.5 ):
#      14  pred='emergency'
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model" is incompatible with the layer: expected shape=(None, 200, 160), found shape=(None, 32039, 1)

# %%
def log_specgram(audio, sample_rate, eps=1e-10):
   nperseg  = 320
   noverlap = 160
   freqs, times, spec = signal.spectrogram(audio,fs=sample_rate,
                           nperseg=nperseg,noverlap=noverlap,detrend=False)
   return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
def plot(spectrogram,label):
 fig = plt.figure(figsize=(14, 8))
 ax = fig.add_subplot(211)
 ax.imshow(spectrogram.T, aspect='auto', origin='lower',extent=[times.min(),
                                 times.max(), freqs.min(), freqs.max()])
 ax.set_title('Spectrogram of '+label)
 ax.set_ylabel('Freqs in Hz')
 ax.set_xlabel('Seconds')

# %%
freqs, times, spectrogram = log_specgram(emergency[300], sample_rate)
plot(spectrogram,"emergency")
freqs, times, spectrogram = log_specgram(non_emergency[300], sample_rate)
plot(spectrogram,"non emergency")

# %%
spectrogram.shape
# Out:
# (199, 161)

# %%
def extract_spectrogram_features(x_tr):
 features=[]
 for i in x_tr:
   _, _, spectrogram = log_specgram(i, sample_rate)
   mean = np.mean(spectrogram, axis=0)
   std = np.std(spectrogram, axis=0)
   spectrogram = (spectrogram - mean) / std
   features.append(spectrogram)
 return np.array(features)

# %%
x_tr_features  = extract_spectrogram_features(x_tr)
x_val_features = extract_spectrogram_features(x_val)

# %%
model, mc = lstm(x_tr_features)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-df0dabf5cb65> in <cell line: 1>()
# ----> 1 model, mc = lstm(x_tr_features)
#       2 model.summary()
#
# TypeError: cannot unpack non-iterable Functional object

# %%
history=model.fit(x_tr_features, y_tr, epochs=10, callbacks=[mc],   batch_size=32, validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 81/85 [===========================>..] - ETA: 0s - loss: 0.6597 - acc: 0.6127
# Epoch 1: val_acc did not improve from 0.84385
# 85/85 [==============================] - 3s 22ms/step - loss: 0.6570 - acc: 0.6161 - val_loss: 0.5828 - val_acc: 0.6877
# Epoch 2/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.4689 - acc: 0.8010
# Epoch 2: val_acc did not improve from 0.84385
# 85/85 [==============================] - 1s 13ms/step - loss: 0.4684 - acc: 0.8016 - val_loss: 0.4775 - val_acc: 0.7608
# Epoch 3/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.3077 - acc: 0.8716
# Epoch 3: val_acc did not improve from 0.84385
# 85/85 [==============================] - 1s 15ms/step - loss: 0.3052 - acc: 0.8730 - val_loss: 0.3982 - val_acc: 0.8239
# Epoch 4/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.1911 - acc: 0.9293
# Epoch 4: val_acc improved from 0.84385 to 0.85714, saving model to best_model.hdf5
# 85/85 [==============================] - 1s 14ms/step - loss: 0.1924 - acc: 0.9285 - val_loss: 0.3450 - val_acc: 0.8571
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1118 - acc: 0.9596
# Epoch 5: val_acc did not improve from 0.85714
# 85/85 [==============================] - 1s 14ms/step - loss: 0.1118 - acc: 0.9596 - val_loss: 0.3613 - val_acc: 0.8439
# Epoch 6/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.0854 - acc: 0.9718
# Epoch 6: val_acc did not improve from 0.85714
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0844 - acc: 0.9722 - val_loss: 0.3605 - val_acc: 0.8538
# Epoch 7/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.0452 - acc: 0.9842
# Epoch 7: val_acc improved from 0.85714 to 0.87043, saving model to best_model.hdf5
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0453 - acc: 0.9845 - val_loss: 0.3262 - val_acc: 0.8704
# Epoch 8/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0816 - acc: 0.9702
# Epoch 8: val_acc did not improve from 0.87043
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0813 - acc: 0.9704 - val_loss: 0.3758 - val_acc: 0.8671
# Epoch 9/10
# 81/85 [===========================>..] - ETA: 0s - loss: 0.0305 - acc: 0.9907
# Epoch 9: val_acc improved from 0.87043 to 0.88372, saving model to best_model.hdf5
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0297 - acc: 0.9911 - val_loss: 0.3043 - val_acc: 0.8837
# Epoch 10/10
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0484 - acc: 0.9806
# Epoch 10: val_acc improved from 0.88372 to 0.90033, saving model to best_model.hdf5
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0474 - acc: 0.9811 - val_loss: 0.2647 - val_acc: 0.9003

# %%
model.load_weights('best_model.hdf5')
_,acc = model.evaluate(x_val_features,y_val)
print("Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2644 - acc: 0.9003
# Accuracy: 0.9003322124481201

# %%
model, mc = conv1d(x_tr_features)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-d309544b09af> in <cell line: 1>()
# ----> 1 model, mc = conv1d(x_tr_features)
#       2 model.summary()
#
# NameError: name 'conv1d' is not defined

# %%
history=model.fit(x_tr_features, y_tr, epochs=10, callbacks=[mc], batch_size=32, validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 81/85 [===========================>..] - ETA: 0s - loss: 0.0369 - acc: 0.9884
# Epoch 1: val_acc did not improve from 0.90033
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0356 - acc: 0.9889 - val_loss: 0.3065 - val_acc: 0.8870
# Epoch 2/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0178 - acc: 0.9948
# Epoch 2: val_acc did not improve from 0.90033
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0178 - acc: 0.9948 - val_loss: 0.2917 - val_acc: 0.9003
# Epoch 3/10
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0198 - acc: 0.9935
# Epoch 3: val_acc improved from 0.90033 to 0.90365, saving model to best_model.hdf5
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0209 - acc: 0.9930 - val_loss: 0.2760 - val_acc: 0.9037
# Epoch 4/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9970
# Epoch 4: val_acc improved from 0.90365 to 0.91362, saving model to best_model.hdf5
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0099 - acc: 0.9970 - val_loss: 0.2934 - val_acc: 0.9136
# Epoch 5/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0129 - acc: 0.9952
# Epoch 5: val_acc did not improve from 0.91362
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0128 - acc: 0.9952 - val_loss: 0.4400 - val_acc: 0.8970
# Epoch 6/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.0213 - acc: 0.9932
# Epoch 6: val_acc did not improve from 0.91362
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0214 - acc: 0.9930 - val_loss: 0.2828 - val_acc: 0.9037
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0084 - acc: 0.9974
# Epoch 7: val_acc did not improve from 0.91362
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0084 - acc: 0.9974 - val_loss: 0.2942 - val_acc: 0.9070
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0068 - acc: 0.9970
# Epoch 8: val_acc did not improve from 0.91362
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0068 - acc: 0.9970 - val_loss: 0.3909 - val_acc: 0.8870
# Epoch 9/10
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0124 - acc: 0.9958
# Epoch 9: val_acc did not improve from 0.91362
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0124 - acc: 0.9959 - val_loss: 0.3235 - val_acc: 0.9037
# Epoch 10/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0073 - acc: 0.9981
# Epoch 10: val_acc improved from 0.91362 to 0.92691, saving model to best_model.hdf5
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0093 - acc: 0.9978 - val_loss: 0.2780 - val_acc: 0.9269

# %%
model.load_weights('best_model.hdf5')
_,acc = model.evaluate(x_val_features,y_val)
print("Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2770 - acc: 0.9269
# Accuracy: 0.9269102811813354
